# %% [markdown]
# <a href="https://colab.research.google.com/github/alirrah/SNUI/blob/master/Copy_of_SN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ntscraper

# %%
import pandas as pd
from ntscraper import Nitter

# %%
scraper = Nitter()
# Out:
# Testing instances: 100%|██████████| 31/31 [00:56<00:00,  1.82s/it]

# %%
tweet = []
user = ['imVkohli']

tmp_user = user
for _ in range(5):
  member = tmp_user.pop()
  tweet_number = scraper.get_profile_info(member)['stats']['tweets']

  tweets = scraper.get_tweets(member , mode='user', number=tweet_number)

  for tweet in tweets['tweets']:
    data = [member, tweet['text'], tweet['date']]
    tweet.append(data)

    if tweet['is_retweet']:
      user.append(tweet['user']['username'][1:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-277dc75d0411> in <cell line: 5>()
#       5 for _ in range(5):
#       6   member = tmp_user.pop()
# ----> 7   tweet_number = scraper.get_profile_info(member)['stats']['tweets']
#       8
#       9   tweets = scraper.get_tweets(member , mode=modes, number=tweet_number)
#
# NameError: name 'scraper' is not defined

# %%
for tweet in tweets['tweets']:
  print(tweet)
  print('-------next tweet--------------')
# Out:
# {'link': 'https://twitter.com/imVkohli/status/1745664399191273793#m', 'text': 'Rewinding to the best bits — From Bollywood Dialogues to deciphering the cool kids’ lingo and so much more. Step into my Unplugged World! 🎬  Watch the full video and all episodes here 🔗bit.ly/3Sdd4DG @StayWrogn #ad', 'user': {'name': 'Virat Kohli', 'username': '@imVkohli', 'profile_id': '1562753500726976514', 'avatar': 'https://pbs.twimg.com/profile_images/1562753500726976514/EPSUNyR3_bigger.jpg'}, 'date': 'Jan 12, 2024 · 4:30 AM UTC', 'is-retweet': False, 'external-link': '', 'replying_to': [], 'quoted-post': {}, 'stats': {'comments': 613, 'retweets': 1158, 'quotes': 39, 'likes': 15617}, 'pictures': [], 'videos': ['https://video.twimg.com/amplify_video/1745311412296077312/pl/yibhc1dMBKIZtlWL.m3u8?tag=14&container=fmp4'], 'gifs': []}
# -------next tweet--------------
# ...

# %%
final_tweet = []
for tweet in tweets['tweets']:
  data = [tweet['link'], tweet['text'], tweet['date'], tweet['stats']['likes'], tweet['stats']['comments']]
  final_tweet.append(data)

# %%
final_tweet
# Out:
# [['https://twitter.com/imVkohli/status/1745664399191273793#m',
#   'Rewinding to the best bits — From Bollywood Dialogues to deciphering the cool kids’ lingo and so much more. Step into my Unplugged World! 🎬  Watch the full video and all episodes here 🔗bit.ly/3Sdd4DG @StayWrogn #ad',
#   'Jan 12, 2024 · 4:30 AM UTC',
#   15617,
#   613],
#  ['https://twitter.com/imVkohli/status/1745000022838497345#m',
#   'Kickstarting 2024 at the Baugh!   Love my new holiday home at Avās Living, Alibaugh. Super excited to give you a sneak peak into my oasis. . . #avasxvirat #inhabityourbestself #alibaug #baughofwonders #luxuryvillas #avaswellness #ad @AvasWellness',
#   'Jan 10, 2024 · 8:30 AM UTC',
#   30637,
#   804],
#  ['https://twitter.com/imVkohli/status/1736612252147450331#m',
# ...

# %%
tweets = scraper.get_tweets('imVkohli', mode='user', number=5)
# Out:
# INFO:root:No instance specified, using random instance https://nitter.in.projectsegfau.lt
# INFO:root:Current stats for imVkohli: 5 tweets, 0 threads...

# %%
data = pd.DataFrame(final_tweet, columns=['link', 'text', 'date', 'likes_no', 'tweets_no'])

# %%
data
# Out:
#                                                 link  \
# 0  https://twitter.com/imVkohli/status/1745664399...
# 1  https://twitter.com/imVkohli/status/1745000022...
# 2  https://twitter.com/imVkohli/status/1736612252...
# 3  https://twitter.com/imVkohli/status/1734800313...
# 4  https://twitter.com/imVkohli/status/1734479723...
#
#                                                 text  \
# 0  Rewinding to the best bits — From Bollywood Di...
# 1  Kickstarting 2024 at the Baugh!   Love my new ...
# 2  #one8CommuneBlr welcomes you to a riotous laun...
# 3  The O’cean Energy Drink sustainable edition is...
# 4                                                  😍
#
#                          date  likes_no  tweets_no
# 0  Jan 12, 2024 · 4:30 AM UTC     15617        613
# 1  Jan 10, 2024 · 8:30 AM UTC     30637        804
# 2  Dec 18, 2023 · 5:00 AM UTC     22696       1182
# 3  Dec 13, 2023 · 5:00 AM UTC     16854        718
# 4  Dec 12, 2023 · 7:46 AM UTC    251194       4168

# %%
def get_tweets(name, modes, no):
  tweets = scraper.get_tweets(name , mode=modes, number=no)

  final_tweet = []

  for tweet in tweets['tweets']:
    data = [tweet['link'], tweet['text'], tweet['date'], tweet['stats']['likes'], tweet['stats']['comments']]
    final_tweet.append(data)

  data = pd.DataFrame(final_tweet, columns=['link', 'text', 'date', 'likes_no', 'tweets_no'])

  return data

# %%
data = get_tweets('imVkohli', 'user', 40)
data
# Out:
# INFO:root:No instance specified, using random instance https://nitter.ktachibana.party
# INFO:root:Current stats for imVkohli: 20 tweets, 0 threads...
# INFO:root:Current stats for imVkohli: 40 tweets, 0 threads...
#                                                  link  \
# 0   https://twitter.com/imVkohli/status/1745664399...
# 1   https://twitter.com/imVkohli/status/1745000022...
# 2   https://twitter.com/imVkohli/status/1736612252...
# 3   https://twitter.com/imVkohli/status/1734800313...
# 4   https://twitter.com/imVkohli/status/1734479723...
# 5   https://twitter.com/imVkohli/status/1734438684...
# 6   https://twitter.com/imVkohli/status/1734075540...
# 7   https://twitter.com/imVkohli/status/1733711859...
# 8   https://twitter.com/imVkohli/status/1732263598...
# 9   https://twitter.com/imVkohli/status/1731538824...
# 10  https://twitter.com/imVkohli/status/1730822129...
# 11  https://twitter.com/imVkohli/status/1729726884...
# ...

# %%
data = get_tweets('RishiSunak', 'hashtag', 10)
data
# Out:
# INFO:root:No instance specified, using random instance https://n.populas.no
# INFO:root:Current stats for RishiSunak: 8 tweets, 0 threads...
# INFO:root:Current stats for RishiSunak: 10 tweets, 0 threads...
#                                                 link  \
# 0  https://twitter.com/DESIblitz/status/174726670...
# 1  https://twitter.com/themacrostory/status/17471...
# 2  https://twitter.com/OgbuakuAgu/status/17472625...
# 3  https://twitter.com/SheelaghG/status/174726217...
# 4  https://twitter.com/sansadflix/status/17472482...
# 5  https://twitter.com/DRMadiha95/status/17472601...
# 6  https://twitter.com/MissyFitLondon/status/1746...
# 7  https://twitter.com/waqas4476/status/174725845...
# 8  https://twitter.com/MacAyeRight/status/1747250...
# 9  https://twitter.com/DESIblitz/status/174724751...
#
#                                                 text  \
# 0  How is Akshata Murty’s savvy philanthropy resu...
# 1  ⚡🚨❗🇬🇧 "War is Coming" - UK Secretary of Defens...
# ...

# %%
data = get_tweets('World cup 2023', 'term', 20)
data
# Out:
# INFO:root:No instance specified, using random instance https://nitter.woodland.cafe
# INFO:root:Current stats for World cup 2023: 12 tweets, 0 threads...
# INFO:root:Current stats for World cup 2023: 20 tweets, 0 threads...
#                                                  link  \
# 0   https://twitter.com/ESPNUK/status/174721202081...
# 1   https://twitter.com/brfootball/status/17470026...
# 2   https://twitter.com/Squawka/status/17470141426...
# 3   https://twitter.com/brfootball/status/17472060...
# 4   https://twitter.com/carIosrma/status/174712525...
# 5   https://twitter.com/jacksClub11011/status/1747...
# 6   https://twitter.com/RealGOA7/status/1747005836...
# 7   https://twitter.com/babarazamking_/status/1746...
# 8   https://twitter.com/Cerebrone/status/174701453...
# 9   https://twitter.com/FlooD_13/status/1747266883...
# 10  https://twitter.com/jacksClub11011/status/1747...
# 11  https://twitter.com/KimmichSZN6/status/1747266...
# ...

# %%
data.to_csv('tweets.csv')

# %%
scraper.get_profile_info('imVkohli')['stats']['tweets']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-bb92b7dc739f> in <cell line: 1>()
# ----> 1 scraper.get_profile_info('imVkohli')['stats']['tweets']
#
# NameError: name 'scraper' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
